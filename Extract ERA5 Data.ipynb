# %%
# !pip install cdsapi

# Configure CDS API credentials
import os
with open(os.path.expanduser('~/.cdsapirc'), 'w') as f:
    f.write('url: https://cds.climate.copernicus.eu/api\n')
    f.write('key: d265d117-1446-461f-afbb-34a33be341dd\n')

# %% [markdown]
# ## ERA5 Temperature Data

# %%
import cdsapi

dataset = "derived-era5-single-levels-daily-statistics"
request = {
    "product_type": "reanalysis",
    "variable": ["2m_temperature"],
    "year": "2000",  # only one year per request
    "month": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"],
    "day": [f"{d:02d}" for d in range(1, 32)],
    "daily_statistic": "daily_mean",
    "time_zone": "utc+00:00",
    "frequency": "6_hourly",
    "area": [75, 43, 74, 44]  # region near NY
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()

# %% [markdown]
# ## ERA5 Soil Moisture Data

# %%
import cdsapi

dataset = "reanalysis-era5-land"
request = {
    "variable": ["volumetric_soil_water_layer_1"],
    "year": "2000",   # one year only
    "month": "01",     # one month only
    "day": [f"{d:02d}" for d in range(1, 32)],
    "time": [f"{h:02d}:00" for h in range(24)],
    "data_format": "netcdf",
    "download_format": "zip"
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
