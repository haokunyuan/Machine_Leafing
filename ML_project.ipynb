# %%
import xarray as xr
import requests
import pandas as pd

# %%
#Leap Data LAI


store = 'gs://leap-persistent/data-library/GLAB-VOD/GLAB-VOD.zarr'
ds = xr.open_dataset(store, engine='zarr', chunks={})

# %%
#ERA5 Variable Names


store = 'gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3'
ds = xr.open_dataset(store, engine='zarr', chunks={})


print(ds.data_vars)
# Out:
# Data variables:
#     100m_u_component_of_wind                                         (time, latitude, longitude) float32 5TB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     100m_v_component_of_wind                                         (time, latitude, longitude) float32 5TB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     10m_u_component_of_neutral_wind                                  (time, latitude, longitude) float32 5TB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     10m_u_component_of_wind                                          (time, latitude, longitude) float32 5TB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     10m_v_component_of_neutral_wind                                  (time, latitude, longitude) float32 5TB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# ...

# %%
#Extracting variables into new dataset

# specify your list of variables (adjust names if necessary):
vars = [
    "total_precipitation",
    "volumetric_soil_water_layer_1",
    "2m_temperature",            # or maybe "temperature_2m"
    "skin_temperature",
    "soil_temperature_level_1",
    "evaporation",
    "surface_solar_radiation_downwards",
    "specific_humidity"
]

# Select only those variables and a time slice if desired:
ds_sub = ds[vars].sel(time=slice("2011-01-01", "2021-12-31"))

ds_sub
# Out:
# <xarray.Dataset> Size: 18TB
# Dimensions:                            (time: 96432, latitude: 721,
#                                         longitude: 1440, level: 37)
# Coordinates:
#   * latitude                           (latitude) float32 3kB 90.0 ... -90.0
#   * level                              (level) int64 296B 1 2 3 ... 950 975 1000
#   * longitude                          (longitude) float32 6kB 0.0 ... 359.8
#   * time                               (time) datetime64[ns] 771kB 2011-01-01...
# Data variables:
#     total_precipitation                (time, latitude, longitude) float32 400GB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     volumetric_soil_water_layer_1      (time, latitude, longitude) float32 400GB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     2m_temperature                     (time, latitude, longitude) float32 400GB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# ...
